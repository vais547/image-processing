# %%
from skimage import io
import matplotlib.pyplot as plt
url='https://cdn.theatlantic.com/thumbor/viW9N1IQLbCrJ0HMtPRvXPXShkU=/0x131:2555x1568/976x549/media/img/mt/2017/06/shutterstock_319985324/original.jpg'
image=io.imread(url)
plt.imshow(image)
plt.show()

# %%
import cv2
import matplotlib.image as mpimg
import matplolib.pyplot as plt

#redaing image files
imag1=cv2.imread('butterfly2.jpg')
imag2=cv2.imread('flower2.jpg')

#Applying numpy addition on images.
fimg1=img1+img2
plt.imshow(fimg1)
plt.show
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [9], in <cell line: 3>()
#       1 import cv2
#       2 import matplotlib.image as mpimg
# ----> 3 import matplolib.pyplot as plt
#       5 #redaing image files
#       6 imag1=cv2.imread('butterfly2.jpg')
#
# ModuleNotFoundError: No module named 'matplolib'

# %%
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img=mpimg.imread('fish.jpg')
plt.imshow(img)
plt.show()

# %%
hsv_img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
light_green=(1,190,200)
dark_green=(18,255,255)
mask=cv2.inRange(hsv_img,light_green,dark_green)
result=cv2.bitwise_and(img,img,mask=mask)
plt.subplot(121)
plt.imshow(mask,cmap="gray")
plt.subplot( 1 ,2, 2)
plt.imshow(result)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 6>()
#       4 mask=cv2.inRange(hsv_img,light_green,dark_green)
#       5 result=cv2.bitwise_and(img,img,mask=mask)
# ----> 6 plt.subplot(121)
#       7 plt.imshow(mask,cmap="gray")
#       8 plt.subplot( 1 ,2, 2)
#
# TypeError: 'tuple' object is not callable

# %%
import cv2
import matplotlib.image as mping
import matplotlib.pyplot as plt
img=mping.imread('fish.jpg')
plt.imshow(img)
plt.show()
