# %%
import cv2
img=cv2.imread('flower2.jpg',0)
cv2.imshow('flower2',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt
image=cv2.imread('flower2.jpg')
plt.imshow(image)
plt.show()

# %%
from PIL import Image
original_Image=Image.open('flower2.jpg')
rotate_image1=original_Image.rotate(180)
rotate_image1.show()

# %%
from PIL import ImageColor
img1=ImageColor.getrgb("yellow")
print(img1)
img2=ImageColor.getrgb("red")
print(img2)
# Out:
# (255, 255, 0)
# (255, 0, 0)

# %%
from PIL import Image
img=Image.new('RGB',(200,400),(255,0,0))
img.show()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('flower2.jpg')
plt.imshow(img)
plt.show()
img=cv2.cvtColor(img,cv2.Color_RGB2HSV)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <cell line: 7>()
#       5 plt.imshow(img)
#       6 plt.show()
# ----> 7 img=cv2.cvtColor(img,cv2.COlor_RGB2HSV)
#       8 plt.show()
#
# AttributeError: module 'cv2' has no attribute 'COlor_RGB2HSV'

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('flower2.jpg')
plt.imshow(img)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.imshow(img)
plt.show()

# %%
image=Image.open('flower2.jpg')
print("Filename:",image.filename)
print("Format:",image.format)
print("mode:",image.mode)
print("size:",image.size)
print("width:",image.width)
print("height:",image.height)
image.close();
# Out:
# Filename: flower2.jpg
# Format: JPEG
# mode: RGB
# size: (239, 211)
# width: 239
# height: 211
